# %%
import pandas as pd
import sklearn
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("portland_housing.csv", index_col=0)
data.head()
# Out:
# C:\Users\abous\AppData\Local\Temp\ipykernel_26544\2179222446.py:1: DtypeWarning: Columns (20,50,161,200) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("portland_housing.csv", index_col=0)
#                         address/city  address/zipcode  bathrooms  bedrooms  \
# abbreviatedAddress
# 2860 NE Blossom Hill Rd     Fairview            97024        3.0       3.0
# 20386 NE Mackenzie Ln       Fairview            97024        3.0       3.0
# 1121 SW 10th Dr              Gresham            97080        3.0       4.0
# 19309 NE Glisan St          Portland            97230        1.0       3.0
# 25-65 NW 20th St             Gresham            97030        3.0       6.0
#
#                                                brokerageName      dateSold  \
# abbreviatedAddress
# 2860 NE Blossom Hill Rd                                  NaN  1.621560e+12
# 20386 NE Mackenzie Ln    Harcourts Real Estate Network Group  1.619140e+12
# ...
